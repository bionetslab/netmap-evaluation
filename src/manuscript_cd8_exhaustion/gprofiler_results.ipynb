# %%
import pandas as pd
import os.path as op

# %%
output_dir = '/data_nfs/og86asub/netmap/netmap-evaluation/results/cd8_usecase_low_ui/genesets/netmap'

activated = pd.read_csv(op.join(output_dir, 'Activated_gprofiler.tsv'), sep = '\t')
print(activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Netmap Activated",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Netmap Activated}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# Bcl2 homodimer complex & CORUM:1988 & 0.05 \\
# immune system process & GO:0002376 & 0.00 \\
# alpha-beta T cell differentiation & GO:0046632 & 0.00 \\
# T cell activation & GO:0042110 & 0.00 \\
# leukocyte activation & GO:0045321 & 0.00 \\
# alpha-beta T cell activation & GO:0046631 & 0.00 \\
# CD8-positive, alpha-beta T cell differentiation & GO:0043374 & 0.00 \\
# cell activation & GO:0001775 & 0.00 \\
# CD8-positive, alpha-beta T cell lineage commitment & GO:0043375 & 0.00 \\
# lymphocyte activation & GO:0046649 & 0.00 \\
# CD8-positive, alpha-beta T cell activation & GO:0036037 & 0.00 \\
# cell morphogenesis & GO:0000902 & 0.00 \\
# T cell differentiation & GO:0030217 & 0.00 \\
# leukocyte differentiation & GO:0002521 & 0.01 \\
# anatomical structure morphogenesis & GO:0009653 & 0.01 \\
# ...

# %%
activated = pd.read_csv(op.join(output_dir, 'Naive_gprofiler.tsv'), sep = '\t')
activated[(activated.highlighted) & (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Netmap Naive",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Netmap Naive}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# Bcl2 homodimer complex & CORUM:1988 & 0.05 \\
# positive regulation of immune system process & GO:0002684 & 0.00 \\
# regulation of immune system process & GO:0002682 & 0.00 \\
# immune system process & GO:0002376 & 0.00 \\
# CD8-positive, alpha-beta T cell lineage commitment & GO:0043375 & 0.00 \\
# immune response & GO:0006955 & 0.00 \\
# T cell activation & GO:0042110 & 0.00 \\
# positive regulation of lymphocyte activation & GO:0051251 & 0.00 \\
# leukocyte activation & GO:0045321 & 0.00 \\
# positive regulation of leukocyte activation & GO:0002696 & 0.00 \\
# positive regulation of cell activation & GO:0050867 & 0.00 \\
# positive regulation of response to stimulus & GO:0048584 & 0.00 \\
# regulation of response to stimulus & GO:0048583 & 0.00 \\
# leukocyte differentiation & GO:0002521 & 0.00 \\
# ...

# %%
activated = pd.read_csv(op.join(output_dir, 'Exhausted_D3_gprofiler.tsv'), sep = '\t')
activated[(activated.highlighted) & (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Netmap Exhausted (D3)",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Netmap Exhausted (D3)}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# Bcl2 homodimer complex & CORUM:1988 & 0.05 \\
# T cell activation & GO:0042110 & 0.00 \\
# regulation of cell adhesion & GO:0030155 & 0.00 \\
# CD8-positive, alpha-beta T cell lineage commitment & GO:0043375 & 0.00 \\
# regulation of lymphocyte activation & GO:0051249 & 0.00 \\
# lymphocyte activation & GO:0046649 & 0.00 \\
# cell-cell adhesion & GO:0098609 & 0.00 \\
# regulation of leukocyte activation & GO:0002694 & 0.00 \\
# positive regulation of lymphocyte activation & GO:0051251 & 0.00 \\
# cell adhesion & GO:0007155 & 0.00 \\
# regulation of cell activation & GO:0050865 & 0.00 \\
# leukocyte activation & GO:0045321 & 0.00 \\
# positive regulation of leukocyte activation & GO:0002696 & 0.00 \\
# cell morphogenesis & GO:0000902 & 0.00 \\
# regulation of leukocyte cell-cell adhesion & GO:1903037 & 0.01 \\
# ...

# %%
activated = pd.read_csv(op.join(output_dir, 'Exhausted_D4_gprofiler.tsv'), sep = '\t')
activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[ (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Netmap Exhausted (D4)",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Netmap Exhausted (D4)}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# Bcl2 homodimer complex & CORUM:1988 & 0.05 \\
# response to cytokine & GO:0034097 & 0.00 \\
# lymphocyte activation & GO:0046649 & 0.00 \\
# response to peptide & GO:1901652 & 0.00 \\
# positive regulation of transcription by RNA polymerase II & GO:0045944 & 0.00 \\
# T cell activation & GO:0042110 & 0.00 \\
# leukocyte activation & GO:0045321 & 0.00 \\
# positive regulation of macromolecule biosynthetic process & GO:0010557 & 0.00 \\
# positive regulation of immune system process & GO:0002684 & 0.00 \\
# positive regulation of biosynthetic process & GO:0009891 & 0.00 \\
# CD8-positive, alpha-beta T cell lineage commitment & GO:0043375 & 0.00 \\
# immune system development & GO:0002520 & 0.00 \\
# cell activation & GO:0001775 & 0.00 \\
# positive regulation of DNA-templated transcription & GO:0045893 & 0.00 \\
# ...

# %%
output_dir_wilc = '/data_nfs/og86asub/netmap/netmap-evaluation/results/cd8_usecase_low_ui/genesets/wilcoxon'
activated = pd.read_csv(op.join(output_dir_wilc, 'Activated_gprofiler.tsv'), sep = '\t')
activated[ (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[(activated.highlighted) & (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Wilcoxon Activated",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
     column_format="p{7cm}ll",        # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Wilcoxon Activated}
# \label{tab:results}
# \begin{tabular}{p{7cm}ll}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# immune response & GO:0006955 & 0.00 \\
# inflammatory response & GO:0006954 & 0.00 \\
# positive regulation of natural killer cell chemotaxis & GO:2000503 & 0.01 \\
# regulation of T-helper 1 cell cytokine production & GO:2000554 & 0.02 \\
# extracellular space & GO:0005615 & 0.00 \\
# cytokine activity & GO:0005125 & 0.00 \\
# tumor necrosis factor receptor binding & GO:0005164 & 0.05 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
activated = pd.read_csv(op.join(output_dir_wilc, 'Naive_gprofiler.tsv'), sep = '\t')
activated[ (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[ (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Wilcoxon Naive",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Wilcoxon Naive}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# cellular response to peptide & GO:1901653 & 0.02 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
activated = pd.read_csv(op.join(output_dir_wilc, 'Exhausted_D3_gprofiler.tsv'), sep = '\t')
activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[(activated.highlighted) & (activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Wilcoxon Exhausted (D3)",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Wilcoxon Exhausted (D3)}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# cell killing & GO:0001906 & 0.00 \\
# granzyme-mediated programmed cell death signaling pathway & GO:0140507 & 0.01 \\
# cytolytic granule & GO:0044194 & 0.01 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
activated = pd.read_csv(op.join(output_dir_wilc, 'Exhausted_D4_gprofiler.tsv'), sep = '\t')
activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']]
print(activated[(activated.significant)].loc[:, ['term_name', 'term_id', 'p_value']].rename(columns = {'term_name': 'Term name', 'term_id': 'GO Term ID', 'p_value': 'P-value'}).to_latex(
    index=False,                 # don't include the DataFrame index
    caption="Wilcoxon Exhausted (D4)",        # add a \caption{}
    label="tab:results",         # add a \label{} for referencing
    float_format="%.2f",         # control decimal precision
    column_format="lcc",         # manually set column alignment (l=left, c=center, r=right)
    escape=True                  # escape special LaTeX characters like _, %, &
))
# Out:
# \begin{table}
# \caption{Wilcoxon Exhausted (D4)}
# \label{tab:results}
# \begin{tabular}{lcc}
# \toprule
# Term name & GO Term ID & P-value \\
# \midrule
# inflammatory response & GO:0006954 & 0.01 \\
# regulation of leukocyte mediated immunity & GO:0002703 & 0.02 \\
# interleukin-18-mediated signaling pathway & GO:0035655 & 0.03 \\
# cellular response to interleukin-18 & GO:0071351 & 0.03 \\
# response to interleukin-18 & GO:0070673 & 0.05 \\
# interleukin-18 receptor complex & GO:0045092 & 0.00 \\
# external side of plasma membrane & GO:0009897 & 0.01 \\
# receptor complex & GO:0043235 & 0.04 \\
# interleukin-18 receptor activity & GO:0042008 & 0.00 \\
# NAD+ nucleosidase activity, cyclic ADP-ribose generating & GO:0061809 & 0.02 \\
# Viral protein interaction with cytokine and cytokine receptor & KEGG:04061 & 0.00 \\
# Interleukin-18 signaling & REAC:R-MMU-9012546 & 0.00 \\
# \bottomrule
# \end{tabular}
# \end{table}
